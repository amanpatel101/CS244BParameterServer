# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from filelock import FileLock
import numpy as np
import ray
import sys
sys.path.append("../")
from consistent_hashing import ConsistentHash
import math 
from time import time
def get_data_loader():
    
    """Safely downloads data. Returns training/validation set dataloader."""
    mnist_transforms = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
    )

    # We add FileLock here because multiple workers will want to
    # download data, and this may cause overwrites since
    # DataLoader is not threadsafe.
    
    class MNISTEvenOddDataset(torch.utils.data.Dataset):
        def __init__(self, ready_data):
            self.img_data = ready_data.data
            self.labels = ready_data.targets % 2
        
        def __len__(self):
            return len(self.labels)
    
        def __getitem__(self, ind):
            return torch.true_divide(self.img_data[ind].view(-1, 28 * 28).squeeze(), 255), torch.tensor([self.labels[ind]])


    
    with FileLock(os.path.expanduser("~/data.lock")):
        
        train_dataset = datasets.MNIST(
                "~/data", train=True, download=True, transform=mnist_transforms
            )
        
        test_dataset = datasets.MNIST("~/data", train=False, transform=mnist_transforms)
        
        train_loader = torch.utils.data.DataLoader(
            MNISTEvenOddDataset(train_dataset),
            batch_size=128,
            shuffle=True,
        )
        test_loader = torch.utils.data.DataLoader(
             MNISTEvenOddDataset(test_dataset),
            batch_size=128,
            shuffle=False,
        )
    return train_loader, test_loader


def evaluate(model, test_loader):
    """Evaluates the accuracy of the model on a validation dataset."""
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(test_loader):
            # This is only set to finish evaluation faster.
            if batch_idx * len(data) > 1024:
                break
            outputs = nn.Sigmoid()(model(data))
            #_, predicted = torch.max(outputs.data, 1)
            predicted = outputs > 0.5
            total += target.size(0)
            correct += (predicted == target).sum().item()
    return 100.0 * correct / total

# %%
class LinearNet(nn.Module):
    """Small Linear Network for MNIST."""

    def __init__(self):
        super(LinearNet, self).__init__()
        self.fc_weights = nn.ParameterList([nn.Parameter(torch.empty(1)) for weight in range(784)])
        init_fc = [nn.init.uniform_(x) for x in self.fc_weights]
        
        self.fc_bias = nn.Parameter(torch.empty(1))
        nn.init.uniform_(self.fc_bias)
        
    #def __init__(self):
    #    super(LinearNet, self).__init__()
    #    self.fc = nn.Linear(28*28, 1)
    #    nn.init.normal(self.fc.weight)

    #def forward(self, x):
    #    x = self.fc(x)
    #    return x
    
    def forward(self, x):
        #fc_layer = torch.cat(tuple(self.fc_weights)).unsqueeze(0)
        #x = x @ fc_layer.T + self.fc_bias
        for i, param in enumerate(self.fc_weights):
            if i==0:
                p=x[:,i]*param
            else:
                p += x[:,i]*param
        x = p.unsqueeze(1) + self.fc_bias
        return x
    
    def get_weights(self):
        return {k: v.cpu() for k, v in self.state_dict().items()}

    def set_weights(self, keys, weights): 
        flatten_weights =  [item for sublist in weights for item in sublist]
        self.load_state_dict({keys[i]:flatten_weights[i] for i in range(len(keys))})
        
    def get_gradients(self, keys):
        grads = {}

        for name, p in self.named_parameters():
            if name in keys:
                grad = None if p.grad is None else p.grad.data.cpu().numpy()
                grads[name] = grad

        return [grads[key] for key in keys]

    def set_gradients(self, gradients):
        for g, p in zip(gradients, self.parameters()):
            if g is not None:
                p.grad = torch.from_numpy(g)

# %%
@ray.remote  
class ParameterServer(object):
    def __init__(self, keys, values):
        self.weights = dict(zip(keys, values))

    def apply_gradients(self, keys, lr, *values):
        summed_gradients = [
            np.stack(gradient_zip).sum(axis=0) for gradient_zip in zip(*values)
        ]
    
        idx = 0
        for key, value in zip(keys, summed_gradients):
            self.weights[key] -= lr * torch.from_numpy(summed_gradients[idx])
            idx+=1

        return [self.weights[key] for key in keys]
    
    def add_weight(self, key, value):
        self.weights[key] = value
    
    def get_weights(self, keys):
        return [self.weights[key] for key in keys]

# %%
@ray.remote
class DataWorker(object):
    def __init__(self, keys):
        self.model = LinearNet()
        self.data_iterator = iter(get_data_loader()[0])
        self.keys = keys
        self.key_set = set(self.keys)
        for key, value in dict(self.model.named_parameters()).items():
            if key not in self.key_set:
                value.requires_grad=False

        
    def update_weights(self, keys, *weights):
        self.model.set_weights(keys, weights)
        
    def update_trainable(self, keys):
        self.keys = keys
        self.key_set = set(self.keys)
        for key, value in dict(self.model.named_parameters()).items():
            if key in self.key_set:
                value.requires_grad = True
            else:
                value.requires_grad = False
       

    def compute_gradients(self):
        #self.model.set_weights(keys, weights)
        try:
            data, target = next(self.data_iterator)
        except StopIteration:  # When the epoch ends, start a new epoch.
            self.data_iterator = iter(get_data_loader()[0])
            data, target = next(self.data_iterator)
        
        self.model.zero_grad()
        output = self.model(data)
        loss = nn.BCEWithLogitsLoss()(output, target.float())
        loss.backward()
        
        return self.model.get_gradients(self.keys)

# %%
iterations = 500
num_workers = 1 # number of workers per server
num_servers = 5 # number of servers
hashes_per_server = 100

def Scheduler(num_servers, hashes_per_server=50):
    
    model = LinearNet()
    key_values = model.get_weights()
    keys = np.array(list(key_values.keys()))
    #print(keys)
    #print(key_values) z
    values = [key_values[key] for key in keys]
    #values = [key_values[key] for key in keys]
    
    key_indices = {key: x for x, key in enumerate(keys)}
   
    # distributing weights across servers - do this using consistency hashing
    server_ids = ["server" + str(ind) for ind in range(num_servers)]
    hasher = ConsistentHash(keys, server_ids, hashes_per_server)
    servers = [ParameterServer.remote(keys[[key_indices[key] for key in hasher.get_keys_per_node()[serv]]], 
                                      [values[key_indices[key]] for key in hasher.get_keys_per_node()[serv]]) for serv in server_ids]
    # servers = [ParameterServer.remote(keys[0:1], values[0:1]), ParameterServer.remote(keys[1:2], values[1:2])]
    
    return hasher, servers, keys, model, hasher.get_keys_per_node(), server_ids.copy()

hasher, servers, keys, model, weight_assignments, server_ids =  Scheduler(num_servers, hashes_per_server)
ray.init(ignore_reinit_error=True)

# creating equal workers per server

workers = [[DataWorker.remote(weight_assignments["server" + str(j)]) for i in range(num_workers)] for j in range(num_servers)]
# Out:
# 2022-05-20 19:22:53,475	INFO worker.py:963 -- Calling ray.init() again after it has already been called.

# %%
len(weight_assignments["server0"])
# Out:
# 785

# %%
test_loader = get_data_loader()[1]

# %%
print("Running synchronous parameter server training.")
lr=0.1
failure_iter=60
failure_server="server4"

# we need to get a new keys order because we are not assuming a ordering in keys
current_weights = []
keys_order = []

for j in range(num_servers):
    keys_order.extend(weight_assignments["server" + str(j)])
    current_weights.extend(ray.get(servers[j].get_weights.remote(weight_assignments["server" + str(j)]))) 
curr_weights_ckpt = current_weights.copy()

time_per_iteration = []
for i in range(iterations):
 
    #start = time()
    
    if i == failure_iter:
        #Define parameters that will need to be moved
        failure_params = weight_assignments[failure_server]
        #Delete server from hash ring and reassign params
        hasher.delete_node_and_reassign_to_others(failure_server)
        weight_assignments = hasher.get_keys_per_node()
        #Update servers and workers
        num_servers -= 1
        server_ind = server_ids.index(failure_server)
        server_ids = server_ids[0 : server_ind] + server_ids[server_ind + 1 : ]
        servers = servers[0 : server_ind] + servers[server_ind + 1 : ]
        workers = workers[0 : server_ind] + workers[server_ind + 1 : ]
        #Add each relevant parameter to its new server
        server_dict = {server_ids[x]:servers[x] for x in range(len(server_ids))}
        for ind, param in enumerate(failure_params):
            server_dict[hasher.get_key_to_node_map()[param]].add_weight.remote(param, curr_weights_ckpt[server_ind][ind])
        #Update these parameters for each worker to make them trainable
        [workers[j][idx].update_trainable.remote(weight_assignments["server" + str(j)]) for  idx  in range(num_workers) for j in range(num_servers)]
        keys_order = []
        for j in range(num_servers):
            keys_order.extend(weight_assignments["server" + str(j)])

    
    # sync all weights on workers
    if i % 10 == 0:
        curr_weights_ckpt = current_weights.copy()
        # get weights from server
        #current_weights = [servers[j].get_weights.remote(weight_assignments["server" + str(j)]) for j in range(num_servers)] 

        # update weights on all workers
        [workers[j][idx].update_weights.remote(keys_order, *current_weights) for  idx  in range(num_workers) for j in range(num_servers)]
    
        
    # use local cache of weights and get gradients from workers
    gradients = [[workers[j][idx].compute_gradients.remote() for  idx  in range(num_workers)] for j in range(num_servers)]

    start = time()
    # Updates gradients to specfic parameter servers
    current_weights_t = [servers[j].apply_gradients.remote(weight_assignments["server" + str(j)], lr, *gradients[j]) for j in range(num_servers)]
    current_weights = ray.get(current_weights_t)
    
    end = time()
    time_per_iteration.append(end-start)

    if i % 10 == 0:
        # Evaluate the current model.
        # current_weights = [servers[j].get_weights.remote(weight_assignments["server" + str(j)]) for j in range(num_servers)] 
      
        # we are once again using the server to key mapping to set the weight back
        model.set_weights(keys_order, current_weights)
        accuracy = evaluate(model, test_loader)
        print("Iter {}: \taccuracy is {:.1f}".format(i, accuracy))
    #rint("\n")

#print("Final accuracy is {:.1f}.".format(accuracy))
# Clean up Ray resources and processes before the next example.
ray.shutdown()
# Out:
# Running synchronous parameter server training.
# Iter 0: 	accuracy is 51.9
# Iter 10: 	accuracy is 51.9
# Iter 20: 	accuracy is 52.4
# Iter 30: 	accuracy is 48.2
# Iter 40: 	accuracy is 65.4
# Iter 50: 	accuracy is 51.6
# Iter 60: 	accuracy is 75.2
# Iter 70: 	accuracy is 48.6
# Iter 80: 	accuracy is 77.4
# Iter 90: 	accuracy is 78.1
# Iter 100: 	accuracy is 78.6
# Iter 110: 	accuracy is 79.4
# Iter 120: 	accuracy is 80.2
# Iter 130: 	accuracy is 81.3
# Iter 140: 	accuracy is 80.6
# Iter 150: 	accuracy is 81.9
# Iter 160: 	accuracy is 81.8
# Iter 170: 	accuracy is 82.2
# Iter 180: 	accuracy is 81.8
# Iter 190: 	accuracy is 82.0
# Iter 200: 	accuracy is 81.8
# Iter 210: 	accuracy is 82.3
# Iter 220: 	accuracy is 82.9
# Iter 230: 	accuracy is 82.9
# Iter 240: 	accuracy is 83.1
# Iter 250: 	accuracy is 83.2
# Iter 260: 	accuracy is 83.2
# Iter 270: 	accuracy is 83.2
# Iter 280: 	accuracy is 82.2
# Iter 290: 	accuracy is 81.7
# Iter 300: 	accuracy is 81.0
# Iter 310: 	accuracy is 80.2
# Iter 320: 	accuracy is 79.3
# Iter 330: 	accuracy is 79.9
# Iter 340: 	accuracy is 79.7
# Iter 350: 	accuracy is 80.6
# Iter 360: 	accuracy is 81.0
# Iter 370: 	accuracy is 84.1
# Iter 380: 	accuracy is 84.0
# Iter 390: 	accuracy is 84.7
# Iter 400: 	accuracy is 84.5
# Iter 410: 	accuracy is 85.5
# Iter 420: 	accuracy is 85.5
# Iter 430: 	accuracy is 85.5
# Iter 440: 	accuracy is 84.7
# Iter 450: 	accuracy is 85.8
# Iter 460: 	accuracy is 85.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14210/1095587891.py in <module>
#      57     # Updates gradients to specfic parameter servers
#      58     current_weights_t = [servers[j].apply_gradients.remote(weight_assignments["server" + str(j)], lr, *gradients[j]) for j in range(num_servers)]
# ---> 59     current_weights = ray.get(current_weights_t)
#      60
#      61     end = time()
#
# ~/anaconda3/envs/ParamServer/lib/python3.7/site-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# ~/anaconda3/envs/ParamServer/lib/python3.7/site-packages/ray/worker.py in get(object_refs, timeout)
#    1801
#    1802         # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1803         values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    1804         for i, value in enumerate(values):
#    1805             if isinstance(value, RayError):
#
# ~/anaconda3/envs/ParamServer/lib/python3.7/site-packages/ray/worker.py in get_objects(self, object_refs, timeout)
#     361         timeout_ms = int(timeout * 1000) if timeout else -1
#     362         data_metadata_pairs = self.core_worker.get_objects(
# --> 363             object_refs, self.current_task_id, timeout_ms
#     364         )
#     365         debugger_breakpoint = b""
#
# KeyboardInterrupt:

# %%
np.mean(time_per_iteration[1:])
# Out:
# 0.28572969966464573

# %%
np.std(time_per_iteration[1:])
# Out:
# 0.014149284267918704

# %%
time_per_iteration

# %%
server_ids
# Out:
# ['server0', 'server1', 'server2', 'server3', 'server4']

# %%
server_ids.index("server4")
# Out:
# 4

# %%
hasher.get_key_to_node_map()['fc_bias']
# Out:
# 'server4'

# %%
testmodel=LinearNet()

# %%
testmodel.get_weights()
# Out:
# {'fc_bias': tensor([0.6657]),
#  'fc_weights.0': tensor([0.8101]),
#  'fc_weights.1': tensor([0.9490]),
#  'fc_weights.2': tensor([0.1687]),
#  'fc_weights.3': tensor([0.3932]),
#  'fc_weights.4': tensor([0.7757]),
#  'fc_weights.5': tensor([0.7350]),
#  'fc_weights.6': tensor([0.7638]),
#  'fc_weights.7': tensor([0.0539]),
#  'fc_weights.8': tensor([0.7448]),
#  'fc_weights.9': tensor([0.7037]),
#  'fc_weights.10': tensor([0.9956]),
#  'fc_weights.11': tensor([0.3894]),
#  'fc_weights.12': tensor([0.9956]),
#  'fc_weights.13': tensor([0.0574]),
#  'fc_weights.14': tensor([0.7612]),
#  'fc_weights.15': tensor([0.6381]),
#  'fc_weights.16': tensor([0.7507]),
#  'fc_weights.17': tensor([0.7583]),
#  'fc_weights.18': tensor([0.9456]),
#  'fc_weights.19': tensor([0.5211]),
#  'fc_weights.20': tensor([0.3994]),
#  'fc_weights.21': tensor([0.7367]),
#  'fc_weights.22': tensor([0.7428]),
#  'fc_weights.23': tensor([0.2396]),
#  'fc_weights.24': tensor([0.4197]),
#  'fc_weights.25': tensor([0.5078]),
#  'fc_weights.26': tensor([0.0744]),
#  'fc_weights.27': tensor([0.6802]),
#  'fc_weights.28': tensor([0.6967]),
#  'fc_weights.29': tensor([0.1901]),
#  'fc_weights.30': tensor([0.1844]),
#  'fc_weights.31': tensor([0.1838]),
#  'fc_weights.32': tensor([0.7290]),
#  'fc_weights.33': tensor([0.6055]),
#  'fc_weights.34': tensor([0.2005]),
#  'fc_weights.35': tensor([0.3661]),
#  'fc_weights.36': tensor([0.7648]),
#  'fc_weights.37': tensor([0.3914]),
#  'fc_weights.38': tensor([0.9028]),
#  'fc_weights.39': tensor([0.4733]),
#  'fc_weights.40': tensor([0.4685]),
#  'fc_weights.41': tensor([0.8471]),
#  'fc_weights.42': tensor([0.0558]),
#  'fc_weights.43': tensor([0.2122]),
#  'fc_weights.44': tensor([0.3798]),
#  'fc_weights.45': tensor([0.2464]),
#  'fc_weights.46': tensor([0.6387]),
#  'fc_weights.47': tensor([0.8338]),
#  'fc_weights.48': tensor([0.7943]),
#  'fc_weights.49': tensor([0.7877]),
#  'fc_weights.50': tensor([0.0711]),
#  'fc_weights.51': tensor([0.1271]),
#  'fc_weights.52': tensor([0.6124]),
#  'fc_weights.53': tensor([0.3859]),
#  'fc_weights.54': tensor([0.2558]),
#  'fc_weights.55': tensor([0.5791]),
#  'fc_weights.56': tensor([0.5781]),
#  'fc_weights.57': tensor([0.5379]),
#  'fc_weights.58': tensor([0.3309]),
#  'fc_weights.59': tensor([0.7822]),
#  'fc_weights.60': tensor([0.1385]),
#  'fc_weights.61': tensor([0.6414]),
#  'fc_weights.62': tensor([0.1261]),
#  'fc_weights.63': tensor([0.5629]),
#  'fc_weights.64': tensor([0.2940]),
#  'fc_weights.65': tensor([0.9973]),
#  'fc_weights.66': tensor([0.6859]),
#  'fc_weights.67': tensor([0.9842]),
#  'fc_weights.68': tensor([0.8811]),
#  'fc_weights.69': tensor([0.3933]),
#  'fc_weights.70': tensor([0.0883]),
#  'fc_weights.71': tensor([0.6568]),
#  'fc_weights.72': tensor([0.7503]),
#  'fc_weights.73': tensor([0.8191]),
#  'fc_weights.74': tensor([0.2360]),
#  'fc_weights.75': tensor([0.3671]),
#  'fc_weights.76': tensor([0.2764]),
#  'fc_weights.77': tensor([0.5907]),
#  'fc_weights.78': tensor([0.8714]),
#  'fc_weights.79': tensor([0.8809]),
#  'fc_weights.80': tensor([0.5935]),
#  'fc_weights.81': tensor([0.2725]),
#  'fc_weights.82': tensor([0.6099]),
#  'fc_weights.83': tensor([0.8807]),
#  'fc_weights.84': tensor([0.2179]),
#  'fc_weights.85': tensor([0.1445]),
#  'fc_weights.86': tensor([0.2735]),
#  'fc_weights.87': tensor([0.2408]),
#  'fc_weights.88': tensor([0.5616]),
#  'fc_weights.89': tensor([0.5412]),
#  'fc_weights.90': tensor([0.5525]),
#  'fc_weights.91': tensor([0.8749]),
#  'fc_weights.92': tensor([0.7160]),
#  'fc_weights.93': tensor([0.5645]),
#  'fc_weights.94': tensor([0.0545]),
#  'fc_weights.95': tensor([0.0783]),
#  'fc_weights.96': tensor([0.4393]),
#  'fc_weights.97': tensor([0.3150]),
#  'fc_weights.98': tensor([0.6474]),
#  'fc_weights.99': tensor([0.4472]),
#  'fc_weights.100': tensor([0.6875]),
#  'fc_weights.101': tensor([0.9122]),
#  'fc_weights.102': tensor([0.8102]),
#  'fc_weights.103': tensor([0.0557]),
#  'fc_weights.104': tensor([0.9013]),
#  'fc_weights.105': tensor([0.4331]),
#  'fc_weights.106': tensor([0.5325]),
#  'fc_weights.107': tensor([0.4528]),
#  'fc_weights.108': tensor([0.9295]),
#  'fc_weights.109': tensor([0.6537]),
#  'fc_weights.110': tensor([0.3421]),
#  'fc_weights.111': tensor([0.0555]),
#  'fc_weights.112': tensor([0.0841]),
#  'fc_weights.113': tensor([0.7530]),
#  'fc_weights.114': tensor([0.1269]),
#  'fc_weights.115': tensor([0.9905]),
#  'fc_weights.116': tensor([0.6056]),
#  'fc_weights.117': tensor([0.4185]),
#  'fc_weights.118': tensor([0.1933]),
#  'fc_weights.119': tensor([0.2991]),
#  'fc_weights.120': tensor([0.7744]),
#  'fc_weights.121': tensor([0.8857]),
#  'fc_weights.122': tensor([0.9244]),
#  'fc_weights.123': tensor([0.3247]),
#  'fc_weights.124': tensor([0.4225]),
#  'fc_weights.125': tensor([0.8345]),
#  'fc_weights.126': tensor([0.5715]),
#  'fc_weights.127': tensor([0.2006]),
#  'fc_weights.128': tensor([0.7015]),
#  'fc_weights.129': tensor([0.8504]),
#  'fc_weights.130': tensor([0.7633]),
#  'fc_weights.131': tensor([0.1592]),
#  'fc_weights.132': tensor([0.2550]),
#  'fc_weights.133': tensor([0.2179]),
#  'fc_weights.134': tensor([0.9107]),
#  'fc_weights.135': tensor([0.6820]),
#  'fc_weights.136': tensor([0.3816]),
#  'fc_weights.137': tensor([0.7007]),
#  'fc_weights.138': tensor([0.5252]),
#  'fc_weights.139': tensor([0.4842]),
#  'fc_weights.140': tensor([0.8691]),
#  'fc_weights.141': tensor([0.0783]),
#  'fc_weights.142': tensor([0.4226]),
#  'fc_weights.143': tensor([0.1392]),
#  'fc_weights.144': tensor([0.5338]),
#  'fc_weights.145': tensor([0.6529]),
#  'fc_weights.146': tensor([0.4081]),
#  'fc_weights.147': tensor([0.0232]),
#  'fc_weights.148': tensor([0.2661]),
#  'fc_weights.149': tensor([0.4494]),
#  'fc_weights.150': tensor([0.1259]),
#  'fc_weights.151': tensor([0.0184]),
#  'fc_weights.152': tensor([0.6528]),
#  'fc_weights.153': tensor([0.2935]),
#  'fc_weights.154': tensor([0.7017]),
#  'fc_weights.155': tensor([0.7586]),
#  'fc_weights.156': tensor([0.8582]),
#  'fc_weights.157': tensor([0.8181]),
#  'fc_weights.158': tensor([0.7355]),
#  'fc_weights.159': tensor([0.9874]),
#  'fc_weights.160': tensor([0.2188]),
#  'fc_weights.161': tensor([0.7321]),
#  'fc_weights.162': tensor([0.1945]),
#  'fc_weights.163': tensor([0.5154]),
#  'fc_weights.164': tensor([0.7227]),
#  'fc_weights.165': tensor([0.5482]),
#  'fc_weights.166': tensor([0.0966]),
#  'fc_weights.167': tensor([0.2465]),
#  'fc_weights.168': tensor([0.2187]),
#  'fc_weights.169': tensor([0.8779]),
#  'fc_weights.170': tensor([0.3202]),
#  'fc_weights.171': tensor([0.3058]),
#  'fc_weights.172': tensor([0.6003]),
#  'fc_weights.173': tensor([0.9763]),
#  'fc_weights.174': tensor([0.6935]),
#  'fc_weights.175': tensor([0.1529]),
#  'fc_weights.176': tensor([0.4038]),
#  'fc_weights.177': tensor([0.0799]),
#  'fc_weights.178': tensor([0.9583]),
#  'fc_weights.179': tensor([0.9710]),
#  'fc_weights.180': tensor([0.9990]),
#  'fc_weights.181': tensor([0.5096]),
#  'fc_weights.182': tensor([0.8000]),
#  'fc_weights.183': tensor([0.5286]),
#  'fc_weights.184': tensor([0.9557]),
#  'fc_weights.185': tensor([0.5165]),
#  'fc_weights.186': tensor([0.2155]),
#  'fc_weights.187': tensor([0.6123]),
#  'fc_weights.188': tensor([0.6873]),
#  'fc_weights.189': tensor([0.7270]),
#  'fc_weights.190': tensor([0.4218]),
#  'fc_weights.191': tensor([0.6096]),
#  'fc_weights.192': tensor([0.5041]),
#  'fc_weights.193': tensor([0.0627]),
#  'fc_weights.194': tensor([0.6550]),
#  'fc_weights.195': tensor([0.4683]),
#  'fc_weights.196': tensor([0.4587]),
#  'fc_weights.197': tensor([0.8629]),
#  'fc_weights.198': tensor([0.5718]),
#  'fc_weights.199': tensor([0.3279]),
#  'fc_weights.200': tensor([0.0181]),
#  'fc_weights.201': tensor([0.5449]),
#  'fc_weights.202': tensor([0.9933]),
#  'fc_weights.203': tensor([0.5679]),
#  'fc_weights.204': tensor([0.8071]),
#  'fc_weights.205': tensor([0.9680]),
#  'fc_weights.206': tensor([0.5427]),
#  'fc_weights.207': tensor([0.2901]),
#  'fc_weights.208': tensor([0.7786]),
#  'fc_weights.209': tensor([0.9854]),
#  'fc_weights.210': tensor([0.6074]),
#  'fc_weights.211': tensor([0.7875]),
#  'fc_weights.212': tensor([0.3646]),
#  'fc_weights.213': tensor([0.9967]),
#  'fc_weights.214': tensor([0.3404]),
#  'fc_weights.215': tensor([0.5485]),
#  'fc_weights.216': tensor([0.0695]),
#  'fc_weights.217': tensor([0.2646]),
#  'fc_weights.218': tensor([0.2880]),
#  'fc_weights.219': tensor([0.3975]),
#  'fc_weights.220': tensor([0.9776]),
#  'fc_weights.221': tensor([0.2509]),
#  'fc_weights.222': tensor([0.9406]),
#  'fc_weights.223': tensor([0.2781]),
#  'fc_weights.224': tensor([0.4037]),
#  'fc_weights.225': tensor([0.7777]),
#  'fc_weights.226': tensor([0.7069]),
#  'fc_weights.227': tensor([0.4413]),
#  'fc_weights.228': tensor([0.4270]),
#  'fc_weights.229': tensor([0.6595]),
#  'fc_weights.230': tensor([0.6643]),
#  'fc_weights.231': tensor([0.7489]),
#  'fc_weights.232': tensor([0.2225]),
#  'fc_weights.233': tensor([0.5144]),
#  'fc_weights.234': tensor([0.6525]),
#  'fc_weights.235': tensor([0.9463]),
#  'fc_weights.236': tensor([0.4375]),
#  'fc_weights.237': tensor([0.7316]),
#  'fc_weights.238': tensor([0.1200]),
#  'fc_weights.239': tensor([0.2472]),
#  'fc_weights.240': tensor([0.3254]),
#  'fc_weights.241': tensor([0.0942]),
#  'fc_weights.242': tensor([0.2365]),
#  'fc_weights.243': tensor([0.4436]),
#  'fc_weights.244': tensor([0.8081]),
#  'fc_weights.245': tensor([0.5754]),
#  'fc_weights.246': tensor([0.7416]),
#  'fc_weights.247': tensor([0.6072]),
#  'fc_weights.248': tensor([0.2804]),
#  'fc_weights.249': tensor([0.1779]),
#  'fc_weights.250': tensor([0.9171]),
#  'fc_weights.251': tensor([0.8896]),
#  'fc_weights.252': tensor([0.0216]),
#  'fc_weights.253': tensor([0.8066]),
#  'fc_weights.254': tensor([0.8052]),
#  'fc_weights.255': tensor([0.5375]),
#  'fc_weights.256': tensor([0.0027]),
#  'fc_weights.257': tensor([0.5275]),
#  'fc_weights.258': tensor([0.3379]),
#  'fc_weights.259': tensor([0.9928]),
#  'fc_weights.260': tensor([0.3517]),
#  'fc_weights.261': tensor([0.2729]),
#  'fc_weights.262': tensor([0.8571]),
#  'fc_weights.263': tensor([0.3802]),
#  'fc_weights.264': tensor([0.4925]),
#  'fc_weights.265': tensor([0.0541]),
#  'fc_weights.266': tensor([0.7396]),
#  'fc_weights.267': tensor([0.7245]),
#  'fc_weights.268': tensor([0.1133]),
#  'fc_weights.269': tensor([0.5823]),
#  'fc_weights.270': tensor([0.1218]),
#  'fc_weights.271': tensor([0.0669]),
#  'fc_weights.272': tensor([0.0652]),
#  'fc_weights.273': tensor([0.5576]),
#  'fc_weights.274': tensor([0.7688]),
#  'fc_weights.275': tensor([0.3170]),
#  'fc_weights.276': tensor([0.5736]),
#  'fc_weights.277': tensor([0.0662]),
#  'fc_weights.278': tensor([0.4095]),
#  'fc_weights.279': tensor([0.8635]),
#  'fc_weights.280': tensor([0.6511]),
#  'fc_weights.281': tensor([0.0408]),
#  'fc_weights.282': tensor([0.6023]),
#  'fc_weights.283': tensor([0.2369]),
#  'fc_weights.284': tensor([0.9824]),
#  'fc_weights.285': tensor([0.7641]),
#  'fc_weights.286': tensor([0.5057]),
#  'fc_weights.287': tensor([0.2996]),
#  'fc_weights.288': tensor([0.9757]),
#  'fc_weights.289': tensor([0.8200]),
#  'fc_weights.290': tensor([0.6172]),
#  'fc_weights.291': tensor([0.7263]),
#  'fc_weights.292': tensor([0.2862]),
#  'fc_weights.293': tensor([0.3677]),
#  'fc_weights.294': tensor([0.9012]),
#  'fc_weights.295': tensor([0.7571]),
#  'fc_weights.296': tensor([0.3914]),
#  'fc_weights.297': tensor([0.7104]),
#  'fc_weights.298': tensor([0.9296]),
#  'fc_weights.299': tensor([0.0982]),
#  'fc_weights.300': tensor([0.9547]),
#  'fc_weights.301': tensor([0.6625]),
#  'fc_weights.302': tensor([0.8813]),
#  'fc_weights.303': tensor([0.9297]),
#  'fc_weights.304': tensor([0.9185]),
#  'fc_weights.305': tensor([0.6345]),
#  'fc_weights.306': tensor([0.7763]),
#  'fc_weights.307': tensor([0.8212]),
#  'fc_weights.308': tensor([0.9466]),
#  'fc_weights.309': tensor([0.0362]),
#  'fc_weights.310': tensor([0.8884]),
#  'fc_weights.311': tensor([0.4756]),
#  'fc_weights.312': tensor([0.3978]),
#  'fc_weights.313': tensor([0.4504]),
#  'fc_weights.314': tensor([0.6648]),
#  'fc_weights.315': tensor([0.9141]),
#  'fc_weights.316': tensor([0.3927]),
#  'fc_weights.317': tensor([0.4879]),
#  'fc_weights.318': tensor([0.3573]),
#  'fc_weights.319': tensor([0.8689]),
#  'fc_weights.320': tensor([0.3141]),
#  'fc_weights.321': tensor([0.2929]),
#  'fc_weights.322': tensor([0.0860]),
#  'fc_weights.323': tensor([0.9818]),
#  'fc_weights.324': tensor([0.3494]),
#  'fc_weights.325': tensor([0.8706]),
#  'fc_weights.326': tensor([0.2780]),
#  'fc_weights.327': tensor([0.2346]),
#  'fc_weights.328': tensor([0.0919]),
#  'fc_weights.329': tensor([0.3427]),
#  'fc_weights.330': tensor([0.0857]),
#  'fc_weights.331': tensor([0.6604]),
#  'fc_weights.332': tensor([0.2720]),
#  'fc_weights.333': tensor([0.1350]),
#  'fc_weights.334': tensor([0.4386]),
#  'fc_weights.335': tensor([0.7217]),
#  'fc_weights.336': tensor([0.4451]),
#  'fc_weights.337': tensor([0.8510]),
#  'fc_weights.338': tensor([0.0701]),
#  'fc_weights.339': tensor([0.2472]),
#  'fc_weights.340': tensor([0.3619]),
#  'fc_weights.341': tensor([0.7155]),
#  'fc_weights.342': tensor([0.7106]),
#  'fc_weights.343': tensor([0.5809]),
#  'fc_weights.344': tensor([0.9071]),
#  'fc_weights.345': tensor([0.9315]),
#  'fc_weights.346': tensor([0.4416]),
#  'fc_weights.347': tensor([0.9796]),
#  'fc_weights.348': tensor([0.7320]),
#  'fc_weights.349': tensor([0.9650]),
#  'fc_weights.350': tensor([0.6150]),
#  'fc_weights.351': tensor([0.4320]),
#  'fc_weights.352': tensor([0.4519]),
#  'fc_weights.353': tensor([0.0753]),
#  'fc_weights.354': tensor([0.8505]),
#  'fc_weights.355': tensor([0.7797]),
#  'fc_weights.356': tensor([0.9601]),
#  'fc_weights.357': tensor([0.6227]),
#  'fc_weights.358': tensor([0.9780]),
#  'fc_weights.359': tensor([0.3895]),
#  'fc_weights.360': tensor([0.8288]),
#  'fc_weights.361': tensor([0.1409]),
#  'fc_weights.362': tensor([0.1688]),
#  'fc_weights.363': tensor([0.7709]),
#  'fc_weights.364': tensor([0.3230]),
#  'fc_weights.365': tensor([0.9852]),
#  'fc_weights.366': tensor([0.5179]),
#  'fc_weights.367': tensor([0.2960]),
#  'fc_weights.368': tensor([0.2435]),
#  'fc_weights.369': tensor([0.6347]),
#  'fc_weights.370': tensor([0.4308]),
#  'fc_weights.371': tensor([0.0557]),
#  'fc_weights.372': tensor([0.2564]),
#  'fc_weights.373': tensor([0.5246]),
#  'fc_weights.374': tensor([0.3250]),
#  'fc_weights.375': tensor([0.0178]),
#  'fc_weights.376': tensor([0.4319]),
#  'fc_weights.377': tensor([0.3755]),
#  'fc_weights.378': tensor([0.4863]),
#  'fc_weights.379': tensor([0.4212]),
#  'fc_weights.380': tensor([0.4867]),
#  'fc_weights.381': tensor([0.7345]),
#  'fc_weights.382': tensor([0.3986]),
#  'fc_weights.383': tensor([0.6025]),
#  'fc_weights.384': tensor([0.4821]),
#  'fc_weights.385': tensor([0.4568]),
#  'fc_weights.386': tensor([0.7512]),
#  'fc_weights.387': tensor([0.9275]),
#  'fc_weights.388': tensor([0.5710]),
#  'fc_weights.389': tensor([0.0561]),
#  'fc_weights.390': tensor([0.2274]),
#  'fc_weights.391': tensor([0.8780]),
#  'fc_weights.392': tensor([0.1955]),
#  'fc_weights.393': tensor([0.6041]),
#  'fc_weights.394': tensor([0.7733]),
#  'fc_weights.395': tensor([0.3374]),
#  'fc_weights.396': tensor([0.3685]),
#  'fc_weights.397': tensor([0.1788]),
#  'fc_weights.398': tensor([0.1197]),
#  'fc_weights.399': tensor([0.7084]),
#  'fc_weights.400': tensor([0.1645]),
#  'fc_weights.401': tensor([0.7560]),
#  'fc_weights.402': tensor([0.9545]),
#  'fc_weights.403': tensor([0.7068]),
#  'fc_weights.404': tensor([0.5915]),
#  'fc_weights.405': tensor([0.3499]),
#  'fc_weights.406': tensor([0.4558]),
#  'fc_weights.407': tensor([0.8246]),
#  'fc_weights.408': tensor([0.8136]),
#  'fc_weights.409': tensor([0.4490]),
#  'fc_weights.410': tensor([0.0895]),
#  'fc_weights.411': tensor([0.8647]),
#  'fc_weights.412': tensor([0.0249]),
#  'fc_weights.413': tensor([0.5797]),
#  'fc_weights.414': tensor([0.9356]),
#  'fc_weights.415': tensor([0.2168]),
#  'fc_weights.416': tensor([0.1916]),
#  'fc_weights.417': tensor([0.9067]),
#  'fc_weights.418': tensor([0.5444]),
#  'fc_weights.419': tensor([0.2944]),
#  'fc_weights.420': tensor([0.7970]),
#  'fc_weights.421': tensor([0.5299]),
#  'fc_weights.422': tensor([0.8402]),
#  'fc_weights.423': tensor([0.4436]),
#  'fc_weights.424': tensor([0.9739]),
#  'fc_weights.425': tensor([0.9866]),
#  'fc_weights.426': tensor([0.5641]),
#  'fc_weights.427': tensor([0.8530]),
#  'fc_weights.428': tensor([0.0916]),
#  'fc_weights.429': tensor([0.3371]),
#  'fc_weights.430': tensor([0.4562]),
#  'fc_weights.431': tensor([0.0804]),
#  'fc_weights.432': tensor([0.9643]),
#  'fc_weights.433': tensor([0.4794]),
#  'fc_weights.434': tensor([0.1372]),
#  'fc_weights.435': tensor([0.5006]),
#  'fc_weights.436': tensor([0.1521]),
#  'fc_weights.437': tensor([0.6653]),
#  'fc_weights.438': tensor([0.8030]),
#  'fc_weights.439': tensor([0.7769]),
#  'fc_weights.440': tensor([0.0460]),
#  'fc_weights.441': tensor([0.0032]),
#  'fc_weights.442': tensor([0.1980]),
#  'fc_weights.443': tensor([0.7466]),
#  'fc_weights.444': tensor([0.0394]),
#  'fc_weights.445': tensor([0.8963]),
#  'fc_weights.446': tensor([0.7401]),
#  'fc_weights.447': tensor([0.3033]),
#  'fc_weights.448': tensor([0.0328]),
#  'fc_weights.449': tensor([0.5320]),
#  'fc_weights.450': tensor([0.5064]),
#  'fc_weights.451': tensor([0.9646]),
#  'fc_weights.452': tensor([0.9126]),
#  'fc_weights.453': tensor([0.7962]),
#  'fc_weights.454': tensor([0.6087]),
#  'fc_weights.455': tensor([0.8904]),
#  'fc_weights.456': tensor([0.4861]),
#  'fc_weights.457': tensor([0.7449]),
#  'fc_weights.458': tensor([0.6619]),
#  'fc_weights.459': tensor([0.3587]),
#  'fc_weights.460': tensor([0.6774]),
#  'fc_weights.461': tensor([0.4482]),
#  'fc_weights.462': tensor([0.4578]),
#  'fc_weights.463': tensor([0.1585]),
#  'fc_weights.464': tensor([0.9369]),
#  'fc_weights.465': tensor([0.5010]),
#  'fc_weights.466': tensor([0.8099]),
#  'fc_weights.467': tensor([0.7532]),
#  'fc_weights.468': tensor([0.5793]),
#  'fc_weights.469': tensor([0.3218]),
#  'fc_weights.470': tensor([0.1074]),
#  'fc_weights.471': tensor([0.2493]),
#  'fc_weights.472': tensor([0.8068]),
#  'fc_weights.473': tensor([0.7948]),
#  'fc_weights.474': tensor([0.1963]),
#  'fc_weights.475': tensor([0.5945]),
#  'fc_weights.476': tensor([0.6715]),
#  'fc_weights.477': tensor([0.6507]),
#  'fc_weights.478': tensor([0.5269]),
#  'fc_weights.479': tensor([0.1715]),
#  'fc_weights.480': tensor([0.4042]),
#  'fc_weights.481': tensor([0.3200]),
#  'fc_weights.482': tensor([0.8532]),
#  'fc_weights.483': tensor([0.8684]),
#  'fc_weights.484': tensor([0.0367]),
#  'fc_weights.485': tensor([0.7556]),
#  'fc_weights.486': tensor([0.3519]),
#  'fc_weights.487': tensor([0.4004]),
#  'fc_weights.488': tensor([0.5788]),
#  'fc_weights.489': tensor([0.2268]),
#  'fc_weights.490': tensor([0.6952]),
#  'fc_weights.491': tensor([0.0401]),
#  'fc_weights.492': tensor([0.7110]),
#  'fc_weights.493': tensor([0.9626]),
#  'fc_weights.494': tensor([0.9699]),
#  'fc_weights.495': tensor([0.7392]),
#  'fc_weights.496': tensor([0.1426]),
#  'fc_weights.497': tensor([0.5413]),
#  'fc_weights.498': tensor([0.9958]),
#  'fc_weights.499': tensor([0.4190]),
#  'fc_weights.500': tensor([0.9466]),
#  'fc_weights.501': tensor([0.7379]),
#  'fc_weights.502': tensor([0.4318]),
#  'fc_weights.503': tensor([0.4158]),
#  'fc_weights.504': tensor([0.3623]),
#  'fc_weights.505': tensor([0.0318]),
#  'fc_weights.506': tensor([0.8820]),
#  'fc_weights.507': tensor([0.9958]),
#  'fc_weights.508': tensor([0.3859]),
#  'fc_weights.509': tensor([0.8552]),
#  'fc_weights.510': tensor([0.5764]),
#  'fc_weights.511': tensor([0.1822]),
#  'fc_weights.512': tensor([0.8941]),
#  'fc_weights.513': tensor([0.6719]),
#  'fc_weights.514': tensor([0.9463]),
#  'fc_weights.515': tensor([0.0520]),
#  'fc_weights.516': tensor([0.1051]),
#  'fc_weights.517': tensor([0.2399]),
#  'fc_weights.518': tensor([0.9623]),
#  'fc_weights.519': tensor([0.1293]),
#  'fc_weights.520': tensor([0.6990]),
#  'fc_weights.521': tensor([0.4294]),
#  'fc_weights.522': tensor([0.1637]),
#  'fc_weights.523': tensor([0.8360]),
#  'fc_weights.524': tensor([0.0819]),
#  'fc_weights.525': tensor([0.9708]),
#  'fc_weights.526': tensor([0.6028]),
#  'fc_weights.527': tensor([0.5362]),
#  'fc_weights.528': tensor([0.8870]),
#  'fc_weights.529': tensor([0.4170]),
#  'fc_weights.530': tensor([0.5602]),
#  'fc_weights.531': tensor([0.0034]),
#  'fc_weights.532': tensor([0.9076]),
#  'fc_weights.533': tensor([0.7954]),
#  'fc_weights.534': tensor([0.4959]),
#  'fc_weights.535': tensor([0.4796]),
#  'fc_weights.536': tensor([0.3569]),
#  'fc_weights.537': tensor([0.0726]),
#  'fc_weights.538': tensor([0.9734]),
#  'fc_weights.539': tensor([0.4597]),
#  'fc_weights.540': tensor([0.7372]),
#  'fc_weights.541': tensor([0.4005]),
#  'fc_weights.542': tensor([0.9052]),
#  'fc_weights.543': tensor([0.0831]),
#  'fc_weights.544': tensor([0.3494]),
#  'fc_weights.545': tensor([0.4567]),
#  'fc_weights.546': tensor([0.0654]),
#  'fc_weights.547': tensor([0.1318]),
#  'fc_weights.548': tensor([0.3916]),
#  'fc_weights.549': tensor([0.3044]),
#  'fc_weights.550': tensor([0.5042]),
#  'fc_weights.551': tensor([0.0532]),
#  'fc_weights.552': tensor([0.8721]),
#  'fc_weights.553': tensor([0.2906]),
#  'fc_weights.554': tensor([0.2462]),
#  'fc_weights.555': tensor([0.8611]),
#  'fc_weights.556': tensor([0.7203]),
#  'fc_weights.557': tensor([0.2984]),
#  'fc_weights.558': tensor([0.1125]),
#  'fc_weights.559': tensor([0.9525]),
#  'fc_weights.560': tensor([0.3932]),
#  'fc_weights.561': tensor([0.3402]),
#  'fc_weights.562': tensor([0.5958]),
#  'fc_weights.563': tensor([0.3283]),
#  'fc_weights.564': tensor([0.8220]),
#  'fc_weights.565': tensor([0.0487]),
#  'fc_weights.566': tensor([0.5684]),
#  'fc_weights.567': tensor([0.4940]),
#  'fc_weights.568': tensor([0.1409]),
#  'fc_weights.569': tensor([0.6302]),
#  'fc_weights.570': tensor([0.9767]),
#  'fc_weights.571': tensor([0.8171]),
#  'fc_weights.572': tensor([0.5405]),
#  'fc_weights.573': tensor([0.5728]),
#  'fc_weights.574': tensor([0.4564]),
#  'fc_weights.575': tensor([0.0953]),
#  'fc_weights.576': tensor([0.7470]),
#  'fc_weights.577': tensor([0.9199]),
#  'fc_weights.578': tensor([0.3755]),
#  'fc_weights.579': tensor([0.0609]),
#  'fc_weights.580': tensor([0.3930]),
#  'fc_weights.581': tensor([0.2223]),
#  'fc_weights.582': tensor([0.4084]),
#  'fc_weights.583': tensor([0.9304]),
#  'fc_weights.584': tensor([0.5869]),
#  'fc_weights.585': tensor([0.9727]),
#  'fc_weights.586': tensor([0.9143]),
#  'fc_weights.587': tensor([0.2098]),
#  'fc_weights.588': tensor([0.6555]),
#  'fc_weights.589': tensor([0.4676]),
#  'fc_weights.590': tensor([0.2335]),
#  'fc_weights.591': tensor([0.8350]),
#  'fc_weights.592': tensor([0.7332]),
#  'fc_weights.593': tensor([0.7658]),
#  'fc_weights.594': tensor([0.4503]),
#  'fc_weights.595': tensor([0.9331]),
#  'fc_weights.596': tensor([0.6254]),
#  'fc_weights.597': tensor([0.0808]),
#  'fc_weights.598': tensor([0.1443]),
#  'fc_weights.599': tensor([0.1034]),
#  'fc_weights.600': tensor([0.4853]),
#  'fc_weights.601': tensor([0.6170]),
#  'fc_weights.602': tensor([0.8801]),
#  'fc_weights.603': tensor([0.3166]),
#  'fc_weights.604': tensor([0.6658]),
#  'fc_weights.605': tensor([0.5085]),
#  'fc_weights.606': tensor([0.1153]),
#  'fc_weights.607': tensor([0.7237]),
#  'fc_weights.608': tensor([0.2140]),
#  'fc_weights.609': tensor([0.4949]),
#  'fc_weights.610': tensor([0.3907]),
#  'fc_weights.611': tensor([0.4790]),
#  'fc_weights.612': tensor([0.3542]),
#  'fc_weights.613': tensor([0.1749]),
#  'fc_weights.614': tensor([0.5047]),
#  'fc_weights.615': tensor([0.2134]),
#  'fc_weights.616': tensor([0.0906]),
#  'fc_weights.617': tensor([0.5808]),
#  'fc_weights.618': tensor([0.6912]),
#  'fc_weights.619': tensor([0.6605]),
#  'fc_weights.620': tensor([0.6178]),
#  'fc_weights.621': tensor([0.7119]),
#  'fc_weights.622': tensor([0.3009]),
#  'fc_weights.623': tensor([0.7093]),
#  'fc_weights.624': tensor([0.4926]),
#  'fc_weights.625': tensor([0.6338]),
#  'fc_weights.626': tensor([0.9414]),
#  'fc_weights.627': tensor([0.2342]),
#  'fc_weights.628': tensor([0.5930]),
#  'fc_weights.629': tensor([0.4639]),
#  'fc_weights.630': tensor([0.0949]),
#  'fc_weights.631': tensor([0.4817]),
#  'fc_weights.632': tensor([0.0146]),
#  'fc_weights.633': tensor([0.6611]),
#  'fc_weights.634': tensor([0.7020]),
#  'fc_weights.635': tensor([0.0192]),
#  'fc_weights.636': tensor([0.2856]),
#  'fc_weights.637': tensor([0.3740]),
#  'fc_weights.638': tensor([0.9555]),
#  'fc_weights.639': tensor([0.1994]),
#  'fc_weights.640': tensor([0.5361]),
#  'fc_weights.641': tensor([0.2308]),
#  'fc_weights.642': tensor([0.3547]),
#  'fc_weights.643': tensor([0.9370]),
#  'fc_weights.644': tensor([0.8313]),
#  'fc_weights.645': tensor([0.6052]),
#  'fc_weights.646': tensor([0.9944]),
#  'fc_weights.647': tensor([0.3346]),
#  'fc_weights.648': tensor([0.7007]),
#  'fc_weights.649': tensor([0.2633]),
#  'fc_weights.650': tensor([0.2378]),
#  'fc_weights.651': tensor([0.0949]),
#  'fc_weights.652': tensor([0.2843]),
#  'fc_weights.653': tensor([0.0908]),
#  'fc_weights.654': tensor([0.9739]),
#  'fc_weights.655': tensor([0.6628]),
#  'fc_weights.656': tensor([0.3977]),
#  'fc_weights.657': tensor([0.1286]),
#  'fc_weights.658': tensor([0.3334]),
#  'fc_weights.659': tensor([0.4658]),
#  'fc_weights.660': tensor([0.4396]),
#  'fc_weights.661': tensor([0.6045]),
#  'fc_weights.662': tensor([0.3994]),
#  'fc_weights.663': tensor([0.0531]),
#  'fc_weights.664': tensor([0.5091]),
#  'fc_weights.665': tensor([0.9548]),
#  'fc_weights.666': tensor([0.8038]),
#  'fc_weights.667': tensor([0.1812]),
#  'fc_weights.668': tensor([0.3570]),
#  'fc_weights.669': tensor([0.6493]),
#  'fc_weights.670': tensor([0.7060]),
#  'fc_weights.671': tensor([0.4772]),
#  'fc_weights.672': tensor([0.1566]),
#  'fc_weights.673': tensor([0.9039]),
#  'fc_weights.674': tensor([0.6160]),
#  'fc_weights.675': tensor([0.2381]),
#  'fc_weights.676': tensor([0.4383]),
#  'fc_weights.677': tensor([0.3672]),
#  'fc_weights.678': tensor([0.9944]),
#  'fc_weights.679': tensor([0.4015]),
#  'fc_weights.680': tensor([0.7338]),
#  'fc_weights.681': tensor([0.7876]),
#  'fc_weights.682': tensor([0.3939]),
#  'fc_weights.683': tensor([0.0051]),
#  'fc_weights.684': tensor([0.2393]),
#  'fc_weights.685': tensor([0.4179]),
#  'fc_weights.686': tensor([0.8817]),
#  'fc_weights.687': tensor([0.8644]),
#  'fc_weights.688': tensor([0.2364]),
#  'fc_weights.689': tensor([0.5320]),
#  'fc_weights.690': tensor([0.9250]),
#  'fc_weights.691': tensor([0.8141]),
#  'fc_weights.692': tensor([0.4148]),
#  'fc_weights.693': tensor([0.0481]),
#  'fc_weights.694': tensor([0.3305]),
#  'fc_weights.695': tensor([0.1520]),
#  'fc_weights.696': tensor([0.4260]),
#  'fc_weights.697': tensor([0.2903]),
#  'fc_weights.698': tensor([0.2898]),
#  'fc_weights.699': tensor([0.7206]),
#  'fc_weights.700': tensor([0.1142]),
#  'fc_weights.701': tensor([0.8007]),
#  'fc_weights.702': tensor([0.9591]),
#  'fc_weights.703': tensor([0.7622]),
#  'fc_weights.704': tensor([0.4928]),
#  'fc_weights.705': tensor([0.7293]),
#  'fc_weights.706': tensor([0.3758]),
#  'fc_weights.707': tensor([0.5780]),
#  'fc_weights.708': tensor([0.4283]),
#  'fc_weights.709': tensor([0.3523]),
#  'fc_weights.710': tensor([0.6645]),
#  'fc_weights.711': tensor([0.4148]),
#  'fc_weights.712': tensor([0.9178]),
#  'fc_weights.713': tensor([0.1805]),
#  'fc_weights.714': tensor([0.8436]),
#  'fc_weights.715': tensor([0.5250]),
#  'fc_weights.716': tensor([0.0167]),
#  'fc_weights.717': tensor([0.7289]),
#  'fc_weights.718': tensor([0.8313]),
#  'fc_weights.719': tensor([0.0777]),
#  'fc_weights.720': tensor([0.0242]),
#  'fc_weights.721': tensor([0.5200]),
#  'fc_weights.722': tensor([0.5050]),
#  'fc_weights.723': tensor([0.3287]),
#  'fc_weights.724': tensor([0.1532]),
#  'fc_weights.725': tensor([0.8131]),
#  'fc_weights.726': tensor([0.6846]),
#  'fc_weights.727': tensor([0.7142]),
#  'fc_weights.728': tensor([0.2609]),
#  'fc_weights.729': tensor([0.1438]),
#  'fc_weights.730': tensor([0.6319]),
#  'fc_weights.731': tensor([0.7361]),
#  'fc_weights.732': tensor([0.1700]),
#  'fc_weights.733': tensor([0.4817]),
#  'fc_weights.734': tensor([0.6254]),
#  'fc_weights.735': tensor([0.4200]),
#  'fc_weights.736': tensor([0.4794]),
#  'fc_weights.737': tensor([0.1589]),
#  'fc_weights.738': tensor([0.4812]),
#  'fc_weights.739': tensor([0.1727]),
#  'fc_weights.740': tensor([0.3695]),
#  'fc_weights.741': tensor([0.9533]),
#  'fc_weights.742': tensor([0.1002]),
#  'fc_weights.743': tensor([0.9024]),
#  'fc_weights.744': tensor([0.4298]),
#  'fc_weights.745': tensor([0.3298]),
#  'fc_weights.746': tensor([0.4723]),
#  'fc_weights.747': tensor([0.3461]),
#  'fc_weights.748': tensor([0.5509]),
#  'fc_weights.749': tensor([0.4119]),
#  'fc_weights.750': tensor([0.1799]),
#  'fc_weights.751': tensor([0.2541]),
#  'fc_weights.752': tensor([0.9717]),
#  'fc_weights.753': tensor([0.8044]),
#  'fc_weights.754': tensor([0.6971]),
#  'fc_weights.755': tensor([0.9466]),
#  'fc_weights.756': tensor([0.8192]),
#  'fc_weights.757': tensor([0.2813]),
#  'fc_weights.758': tensor([0.7833]),
#  'fc_weights.759': tensor([0.3099]),
#  'fc_weights.760': tensor([0.2680]),
#  'fc_weights.761': tensor([0.2576]),
#  'fc_weights.762': tensor([0.5217]),
#  'fc_weights.763': tensor([0.4252]),
#  'fc_weights.764': tensor([0.8160]),
#  'fc_weights.765': tensor([0.8377]),
#  'fc_weights.766': tensor([0.6549]),
#  'fc_weights.767': tensor([0.9459]),
#  'fc_weights.768': tensor([0.7395]),
#  'fc_weights.769': tensor([0.0738]),
#  'fc_weights.770': tensor([0.2675]),
#  'fc_weights.771': tensor([0.0538]),
#  'fc_weights.772': tensor([0.5643]),
#  'fc_weights.773': tensor([0.4944]),
#  'fc_weights.774': tensor([0.1360]),
#  'fc_weights.775': tensor([0.0829]),
#  'fc_weights.776': tensor([0.0038]),
#  'fc_weights.777': tensor([0.0111]),
#  'fc_weights.778': tensor([0.7068]),
#  'fc_weights.779': tensor([0.6958]),
#  'fc_weights.780': tensor([0.2658]),
#  'fc_weights.781': tensor([0.6807]),
#  'fc_weights.782': tensor([0.9140]),
#  'fc_weights.783': tensor([0.2675])}

# %%
len(current_weights[0])
# Out:
# 160

# %%
servers[0].weights
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14210/1032609814.py in <module>
# ----> 1 servers[0].weights
#
# ~/anaconda3/envs/ParamServer/lib/python3.7/site-packages/ray/actor.py in __getattr__(self, item)
#    1187         if not self._ray_is_cross_language:
#    1188             raise AttributeError(
# -> 1189                 f"'{type(self).__name__}' object has " f"no attribute '{item}'"
#    1190             )
#    1191         if item in ["__ray_terminate__", "__ray_checkpoint__"]:
#
# AttributeError: 'ActorHandle' object has no attribute 'weights'

# %%
sum([184, 198, 191, 212])
# Out:
# 785
